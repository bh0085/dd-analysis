# %%
import pysam
import os
import pandas as pd
from Bio import SeqIO
import pandas as pd
import re
import numpy as np
from goatools.go_enrichment import GOEnrichmentStudy
from goatools import obo_parser

import wget

DATA_DIR = "/data/dd-analysis"

#LOAD DATABASE ANNOTATIONS
refseq_genes = pd.read_csv("/data/genomes/annotations/refseq_genes_export.csv", delimiter="\t")
entrez = pd.read_csv("/data/genomes/annotations/Homo_sapiens.GRCh38.95.entrez.tsv",delimiter = "\t")
refseq_xref = pd.read_csv("/data/genomes/annotations/Homo_sapiens.GRCh38.95.refseq.tsv",delimiter = "\t")


#LOAD GENE ONTOLOGIES FOR HG38
from Bio.UniProt import GOA
fopen = open("/data/genomes/annotations/goa_human.gaf")
itr = GOA.gafiterator(fopen)
records = list(itr)
ontologies = pd.DataFrame.from_dict(records)    

dsname = 5838205499823053
#dsname = dataset["dataset"]

#READ TRANSCRIPT ALIGNMENTS
samfile = pysam.AlignmentFile("/data/dd-analysis/datasets/{}/tophat/accepted_hits.bam".format(dsname), "rb")
all_alignments = [a for a in  samfile]
names =[e.reference_name for e in all_alignments]
query_names = [e.query_name for e in all_alignments]

#LOAD TRANSCRIPTOME FASTA FILE
#this is the file that the reads above were aligned to and contains add'l annotations
with open("/data/transcriptomes/Homo_sapiens.GRCh38.cdna.all.fa") as f:
    farecords = SeqIO.parse(f, "fasta")
    recs = [r for r in farecords]
for r in recs:
    r.id = r.id[:r.id.index(".")]

# %%
gsre = re.compile("gene_symbol:(\S+)")
dre = re.compile("description:(.*)")
chromre = re.compile("chromosome:(\S+)")
genere = re.compile("gene:(\S+)")

transcript_gene_symbols = dict([(r.id, gsre.search(r.description).groups()[0]) for r in recs if "gene_symbol:" in r.description])
transcript_descriptions = dict([(r.id, dre.search(r.description).groups()[0]) for r in recs if "description:" in r.description])
transcript_chromosome = dict([(r.id, chromre.search(r.description).groups()[0]) for r in recs if "chromosome:" in r.description])
transcript_geneid_withversion = dict([(r.id, genere.search(r.description).groups()[0]) for r in recs if "description:" in r.description])
transcript_geneid = dict([(k,v[:v.index(".")]) for k, v in transcript_geneid_withversion.items()])
entrez_by_gene = entrez.drop_duplicates("gene_stable_id").set_index(entrez.drop_duplicates("gene_stable_id").gene_stable_id)
mapped_genes = set(g for g in transcript_geneid.values() if entrez_by_gene.index.contains(g))
transcript_xref = dict([(k ,entrez_by_gene.loc[g].xref if g in mapped_genes else None) for k,g in transcript_geneid.items() ])


#many-to-one mapping between UMI_IDS and transcripts
umi2tx = pd.DataFrame.from_dict([{"umi_id":qn,"dataset":qn.split("_")[0],"umi":qn.split("_")[1],"transcript":names[i][:names[i].index(".")]} 
                                for i,qn in enumerate(query_names)])

#mappping from transcript gene symbols (recorded in the ensembl cdna file to 
#refseq genes

refseq_symbol_names_jointable = pd.concat([refseq_genes.name2,refseq_genes.name],axis = 1)
refseq_symbols_idx = pd.Index(refseq_genes.name2.drop_duplicates().str.upper())
refseq_symbol_ids = pd.Series(refseq_genes.name2.drop_duplicates().index, index=refseq_symbols_idx)

tx_symbols = pd.Series(transcript_gene_symbols)
refseq_matches = tx_symbols.apply(lambda x: refseq_symbol_ids[x] if x in refseq_symbols_idx else None).dropna()
#roughly 85% of transcripts can be matched refseq IDs
transcript_refseqs = refseq_matches.apply(lambda x: refseq_genes.name.loc[x])

TX_INFO = pd.concat([pd.Series(transcript_descriptions).rename("desc"),
                 pd.Series(transcript_gene_symbols).rename("symbol"),
                pd.Series(transcript_geneid).rename("ensembl_gene"),
                 pd.Series(transcript_xref).rename("ncbi_gene")
                ],axis = 1, sort=True)

all_umis = umi2tx.umi_id.unique()


#GOTTA REMEMBER TO FILTER OUT ALL SHITTY UMIS!
nosegfeat_fn = f"/data/tmp/watch_sequences/{dsname}/xumi_feat_{dsname}"
nosegfeat_df = pd.read_csv(nosegfeat_fn,names=["umi","check","blank1","blank2","sequence"])
nosegfeat_df.iloc[:,1].unique()
good_umis_idx = nosegfeat_df.loc[nosegfeat_df.iloc[:,1]==0].index

segfn = f"/data/tmp/watch_sequences/{dsname}/xumi_segment_base_{dsname}"
segdf = pd.read_csv(segfn,names=["umi","seg","1","2","3"]).loc[good_umis_idx]

go_obo_url = 'http://purl.obolibrary.org/obo/go/go-basic.obo'
data_folder = '/data/go'

# Check if we have the ./data directory already
if(not os.path.isfile(data_folder)):
    # Emulate mkdir -p (no error if folder exists)
    try:
        os.mkdir(data_folder)
    except OSError as e:
        if(e.errno != 17):
            raise e
else:
    raise Exception('Data path (' + data_folder + ') exists as a file. '
                   'Please rename, remove or change the desired location of the data path.')

# Check if the file exists already
if(not os.path.isfile(data_folder+'/go-basic.obo')):
    go_obo = wget.download(go_obo_url, data_folder+'/go-basic.obo')
else:
    go_obo = data_folder+'/go-basic.obo'

# Import the OBO parser from GOATools
go = obo_parser.GODag(go_obo)
# Out:
# /data/go/go-basic.obo: fmt(1.2) rel(2019-03-19) 47,381 GO Terms
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-87e880fd4771> in <module>
#      74
#      75
# ---> 76 raise Exception()()
#      77
#      78 a0 = ontologies.sort_values("DB_Object_Symbol")
#
# TypeError: 'Exception' object is not callable

# %%
len(ontologies)
# Out:
# 476348

# %%
len(a0)
# Out:
# 476348

# %%
len(umi2txall)
# Out:
# 57102

# %%
len(umi2go)
# Out:
# 713468

# %%
ontologies.loc[ontologies.DB_Object_Symbol == "ARF4"]
# Out:
#                                      Annotation_Extension Aspect Assigned_By  \
# 110902                                                         F    Reactome
# 110903                                                         F    Reactome
# 110904                                                         F    Reactome
# 110905                                                         F    Reactome
# 110906                                                         F     UniProt
# 110907                                                         F     UniProt
# 110908                                                         F      IntAct
# 110909                                                         F      IntAct
# 110910                                                         F      IntAct
# 110911                                                         F     UniProt
# 110912                                                         C     UniProt
# 110913                                                         C    Reactome
# 110914                                                         C    Reactome
# 110915                                                         C    Reactome
# 110916                                                         C    Reactome
# 110917                                                         C    Reactome
# 110918                                                         C    Reactome
# 110919                                                         C    Reactome
# 110920                                                         C    Reactome
# 110921                                                         C    Reactome
# 110922                                                         C    Reactome
# 110923                                                         C    Reactome
# 110924                                                         C    Reactome
# 110925                                                         C    Reactome
# 110926                                                         C    Reactome
# 110927                                                         P     UniProt
# 110928                                                         P    Reactome
# 110929  transports_or_maintains_localization_of(UniPro...      P    WormBase
# 110930  transports_or_maintains_localization_of(UniPro...      P    WormBase
# 110931                                                         P    Reactome
# 110932                                                         P     Ensembl
# 110933                                                         P     Ensembl
# 110934                                                         P     Ensembl
# 110935                                                         C     UniProt
# 110936                                                         P     UniProt
# 110937                                                         P     UniProt
# 110938                                                         C     UniProt
# 110939                                                         P     UniProt
# 110940                                                         C         MGI
# 110941                                                         P     Ensembl
# 110942                                                         P     Ensembl
# 110943                                                         P     UniProt
# 110944                                                         P     Ensembl
# 110945                                                         P         MGI
# 110946                                                         P     Ensembl
# 110947                                part_of(CL:0000639)      C     UniProt
# 110948                                                         C     Ensembl
# 110949                                                         P     Ensembl
# 110950                                                         P     UniProt
# 427558                                                         P  GO_Central
# 432761                                                         C  GO_Central
# 433512                                                         P  GO_Central
# 434163                                                         P  GO_Central
# 436322                                                         F  GO_Central
# 469812                                                         P  GO_Central
# 473198                                                         C  GO_Central
# 473793                                                         C  GO_Central
#
#                DB              DB:Reference DB_Object_ID  \
# 110902  UniProtKB  [Reactome:R-HSA-5623513]       P18085
# 110903  UniProtKB  [Reactome:R-HSA-6807877]       P18085
# 110904  UniProtKB  [Reactome:R-HSA-6811414]       P18085
# 110905  UniProtKB  [Reactome:R-HSA-6811418]       P18085
# 110906  UniProtKB           [PMID:12446727]       P18085
# 110907  UniProtKB           [PMID:17956946]       P18085
# 110908  UniProtKB           [PMID:21988832]       P18085
# 110909  UniProtKB           [PMID:25416956]       P18085
# 110910  UniProtKB           [PMID:26258637]       P18085
# 110911  UniProtKB           [PMID:12446727]       P18085
# 110912  UniProtKB           [PMID:12446727]       P18085
# 110913  UniProtKB  [Reactome:R-HSA-5620914]       P18085
# 110914  UniProtKB  [Reactome:R-HSA-5620921]       P18085
# 110915  UniProtKB  [Reactome:R-HSA-5623508]       P18085
# 110916  UniProtKB  [Reactome:R-HSA-5623513]       P18085
# 110917  UniProtKB  [Reactome:R-HSA-6807866]       P18085
# 110918  UniProtKB  [Reactome:R-HSA-6807868]       P18085
# 110919  UniProtKB  [Reactome:R-HSA-6807872]       P18085
# 110920  UniProtKB  [Reactome:R-HSA-6807875]       P18085
# 110921  UniProtKB  [Reactome:R-HSA-6807877]       P18085
# 110922  UniProtKB  [Reactome:R-HSA-6811411]       P18085
# 110923  UniProtKB  [Reactome:R-HSA-6811412]       P18085
# 110924  UniProtKB  [Reactome:R-HSA-6811414]       P18085
# 110925  UniProtKB  [Reactome:R-HSA-6811417]       P18085
# 110926  UniProtKB  [Reactome:R-HSA-6811418]       P18085
# 110927  UniProtKB            [PMID:1899243]       P18085
# 110928  UniProtKB   [Reactome:R-HSA-199977]       P18085
# 110929  UniProtKB           [PMID:24768165]       P18085
# 110930  UniProtKB           [PMID:24768165]       P18085
# 110931  UniProtKB  [Reactome:R-HSA-6811434]       P18085
# 110932  UniProtKB          [GO_REF:0000107]       P18085
# 110933  UniProtKB          [GO_REF:0000107]       P18085
# 110934  UniProtKB          [GO_REF:0000107]       P18085
# 110935  UniProtKB           [PMID:19946888]       P18085
# 110936  UniProtKB           [PMID:22004728]       P18085
# 110937  UniProtKB           [PMID:12446727]       P18085
# 110938  UniProtKB           [PMID:12446727]       P18085
# 110939  UniProtKB           [PMID:19041174]       P18085
# 110940  UniProtKB           [PMID:23050017]       P18085
# 110941  UniProtKB          [GO_REF:0000107]       P18085
# 110942  UniProtKB          [GO_REF:0000107]       P18085
# 110943  UniProtKB           [PMID:12446727]       P18085
# 110944  UniProtKB          [GO_REF:0000107]       P18085
# 110945  UniProtKB           [PMID:23050017]       P18085
# 110946  UniProtKB          [GO_REF:0000107]       P18085
# 110947  UniProtKB           [PMID:20458337]       P18085
# 110948  UniProtKB          [GO_REF:0000107]       P18085
# 110949  UniProtKB          [GO_REF:0000107]       P18085
# 110950  UniProtKB           [PMID:19041174]       P18085
# 427558  UniProtKB           [PMID:21873635]       P18085
# 432761  UniProtKB           [PMID:21873635]       P18085
# 433512  UniProtKB           [PMID:21873635]       P18085
# 434163  UniProtKB           [PMID:21873635]       P18085
# 436322  UniProtKB           [PMID:21873635]       P18085
# 469812  UniProtKB           [PMID:21873635]       P18085
# 473198  UniProtKB           [PMID:21873635]       P18085
# 473793  UniProtKB           [PMID:21873635]       P18085
#
#                    DB_Object_Name DB_Object_Symbol DB_Object_Type      Date  \
# 110902  ADP-ribosylation factor 4             ARF4        protein  20140912
# 110903  ADP-ribosylation factor 4             ARF4        protein  20151109
# 110904  ADP-ribosylation factor 4             ARF4        protein  20151119
# 110905  ADP-ribosylation factor 4             ARF4        protein  20151124
# 110906  ADP-ribosylation factor 4             ARF4        protein  20130904
# 110907  ADP-ribosylation factor 4             ARF4        protein  20150203
# 110908  ADP-ribosylation factor 4             ARF4        protein  20190212
# 110909  ADP-ribosylation factor 4             ARF4        protein  20190212
# 110910  ADP-ribosylation factor 4             ARF4        protein  20190212
# 110911  ADP-ribosylation factor 4             ARF4        protein  20130904
# 110912  ADP-ribosylation factor 4             ARF4        protein  20130904
# 110913  ADP-ribosylation factor 4             ARF4        protein  20140912
# 110914  ADP-ribosylation factor 4             ARF4        protein  20140912
# 110915  ADP-ribosylation factor 4             ARF4        protein  20140912
# 110916  ADP-ribosylation factor 4             ARF4        protein  20140912
# 110917  ADP-ribosylation factor 4             ARF4        protein  20140912
# 110918  ADP-ribosylation factor 4             ARF4        protein  20140912
# 110919  ADP-ribosylation factor 4             ARF4        protein  20140912
# 110920  ADP-ribosylation factor 4             ARF4        protein  20140912
# 110921  ADP-ribosylation factor 4             ARF4        protein  20140912
# 110922  ADP-ribosylation factor 4             ARF4        protein  20140912
# 110923  ADP-ribosylation factor 4             ARF4        protein  20140912
# 110924  ADP-ribosylation factor 4             ARF4        protein  20140912
# 110925  ADP-ribosylation factor 4             ARF4        protein  20140912
# 110926  ADP-ribosylation factor 4             ARF4        protein  20140912
# 110927  ADP-ribosylation factor 4             ARF4        protein  20130904
# 110928  ADP-ribosylation factor 4             ARF4        protein  20181122
# 110929  ADP-ribosylation factor 4             ARF4        protein  20160331
# 110930  ADP-ribosylation factor 4             ARF4        protein  20160331
# 110931  ADP-ribosylation factor 4             ARF4        protein  20181122
# 110932  ADP-ribosylation factor 4             ARF4        protein  20190211
# 110933  ADP-ribosylation factor 4             ARF4        protein  20190211
# 110934  ADP-ribosylation factor 4             ARF4        protein  20190211
# 110935  ADP-ribosylation factor 4             ARF4        protein  20140627
# 110936  ADP-ribosylation factor 4             ARF4        protein  20130904
# 110937  ADP-ribosylation factor 4             ARF4        protein  20130904
# 110938  ADP-ribosylation factor 4             ARF4        protein  20130904
# 110939  ADP-ribosylation factor 4             ARF4        protein  20130904
# 110940  ADP-ribosylation factor 4             ARF4        protein  20150416
# 110941  ADP-ribosylation factor 4             ARF4        protein  20190211
# 110942  ADP-ribosylation factor 4             ARF4        protein  20190211
# 110943  ADP-ribosylation factor 4             ARF4        protein  20130904
# 110944  ADP-ribosylation factor 4             ARF4        protein  20190211
# 110945  ADP-ribosylation factor 4             ARF4        protein  20150416
# 110946  ADP-ribosylation factor 4             ARF4        protein  20190211
# 110947  ADP-ribosylation factor 4             ARF4        protein  20130829
# 110948  ADP-ribosylation factor 4             ARF4        protein  20190211
# 110949  ADP-ribosylation factor 4             ARF4        protein  20190211
# 110950  ADP-ribosylation factor 4             ARF4        protein  20130904
# 427558  ADP-ribosylation factor 4             ARF4        protein  20171006
# 432761  ADP-ribosylation factor 4             ARF4        protein  20171006
# 433512  ADP-ribosylation factor 4             ARF4        protein  20171006
# 434163  ADP-ribosylation factor 4             ARF4        protein  20171006
# 436322  ADP-ribosylation factor 4             ARF4        protein  20171006
# 469812  ADP-ribosylation factor 4             ARF4        protein  20171006
# 473198  ADP-ribosylation factor 4             ARF4        protein  20171006
# 473793  ADP-ribosylation factor 4             ARF4        protein  20171006
#
#        Evidence       GO_ID Gene_Product_Form_ID Qualifier       Synonym  \
# 110902      TAS  GO:0003924                             []  [ARF4, ARF2]
# 110903      TAS  GO:0003924                             []  [ARF4, ARF2]
# 110904      TAS  GO:0005086                             []  [ARF4, ARF2]
# 110905      TAS  GO:0005086                             []  [ARF4, ARF2]
# 110906      IDA  GO:0005154                             []  [ARF4, ARF2]
# 110907      IPI  GO:0005515                             []  [ARF4, ARF2]
# 110908      IPI  GO:0005515                             []  [ARF4, ARF2]
# 110909      IPI  GO:0005515                             []  [ARF4, ARF2]
# 110910      IPI  GO:0005515                             []  [ARF4, ARF2]
# 110911      IDA  GO:0005525                             []  [ARF4, ARF2]
# 110912      IDA  GO:0005829                             []  [ARF4, ARF2]
# 110913      TAS  GO:0005829                             []  [ARF4, ARF2]
# 110914      TAS  GO:0005829                             []  [ARF4, ARF2]
# 110915      TAS  GO:0005829                             []  [ARF4, ARF2]
# 110916      TAS  GO:0005829                             []  [ARF4, ARF2]
# 110917      TAS  GO:0005829                             []  [ARF4, ARF2]
# 110918      TAS  GO:0005829                             []  [ARF4, ARF2]
# 110919      TAS  GO:0005829                             []  [ARF4, ARF2]
# 110920      TAS  GO:0005829                             []  [ARF4, ARF2]
# 110921      TAS  GO:0005829                             []  [ARF4, ARF2]
# 110922      TAS  GO:0005829                             []  [ARF4, ARF2]
# 110923      TAS  GO:0005829                             []  [ARF4, ARF2]
# 110924      TAS  GO:0005829                             []  [ARF4, ARF2]
# 110925      TAS  GO:0005829                             []  [ARF4, ARF2]
# 110926      TAS  GO:0005829                             []  [ARF4, ARF2]
# 110927      IDA  GO:0006471                             []  [ARF4, ARF2]
# 110928      TAS  GO:0006888                             []  [ARF4, ARF2]
# 110929      IGI  GO:0006890                             []  [ARF4, ARF2]
# 110930      IGI  GO:0006890                             []  [ARF4, ARF2]
# 110931      TAS  GO:0006890                             []  [ARF4, ARF2]
# 110932      IEA  GO:0007173                             []  [ARF4, ARF2]
# 110933      IEA  GO:0007420                             []  [ARF4, ARF2]
# 110934      IEA  GO:0007612                             []  [ARF4, ARF2]
# 110935      HDA  GO:0016020                             []  [ARF4, ARF2]
# 110936      IDA  GO:0016477                             []  [ARF4, ARF2]
# 110937      IDA  GO:0031584                             []  [ARF4, ARF2]
# 110938      IDA  GO:0032587                             []  [ARF4, ARF2]
# 110939      IDA  GO:0043066                             []  [ARF4, ARF2]
# 110940      IDA  GO:0043197                             []  [ARF4, ARF2]
# 110941      IEA  GO:0045176                             []  [ARF4, ARF2]
# 110942      IEA  GO:0045197                             []  [ARF4, ARF2]
# 110943      IDA  GO:0045944                             []  [ARF4, ARF2]
# 110944      IEA  GO:0048678                             []  [ARF4, ARF2]
# 110945      IDA  GO:0060996                             []  [ARF4, ARF2]
# 110946      IEA  GO:0061512                             []  [ARF4, ARF2]
# 110947      HDA  GO:0070062                             []  [ARF4, ARF2]
# 110948      IEA  GO:0098978                             []  [ARF4, ARF2]
# 110949      IEA  GO:0099175                             []  [ARF4, ARF2]
# 110950      IDA  GO:2000377                             []  [ARF4, ARF2]
# 427558      IBA  GO:0016192                             []  [ARF4, ARF2]
# 432761      IBA  GO:0005794                             []  [ARF4, ARF2]
# 433512      IBA  GO:0006886                             []  [ARF4, ARF2]
# 434163      IBA  GO:0006893                             []  [ARF4, ARF2]
# 436322      IBA  GO:0005525                             []  [ARF4, ARF2]
# 469812      IBA  GO:0006890                             []  [ARF4, ARF2]
# 473198      IBA  GO:0005737                             []  [ARF4, ARF2]
# 473793      IBA  GO:0005886                             []  [ARF4, ARF2]
#
#             Taxon_ID                                               With
# 110902  [taxon:9606]                                                 []
# 110903  [taxon:9606]                                                 []
# 110904  [taxon:9606]                                                 []
# 110905  [taxon:9606]                                                 []
# 110906  [taxon:9606]                                                 []
# 110907  [taxon:9606]                                 [UniProtKB:Q92538]
# 110908  [taxon:9606]                                 [UniProtKB:Q96PM5]
# 110909  [taxon:9606]                                 [UniProtKB:Q9H190]
# 110910  [taxon:9606]                               [UniProtKB:O75154-1]
# 110911  [taxon:9606]                                                 []
# 110912  [taxon:9606]                                                 []
# 110913  [taxon:9606]                                                 []
# 110914  [taxon:9606]                                                 []
# 110915  [taxon:9606]                                                 []
# 110916  [taxon:9606]                                                 []
# 110917  [taxon:9606]                                                 []
# 110918  [taxon:9606]                                                 []
# 110919  [taxon:9606]                                                 []
# 110920  [taxon:9606]                                                 []
# 110921  [taxon:9606]                                                 []
# 110922  [taxon:9606]                                                 []
# 110923  [taxon:9606]                                                 []
# 110924  [taxon:9606]                                                 []
# 110925  [taxon:9606]                                                 []
# 110926  [taxon:9606]                                                 []
# 110927  [taxon:9606]                                                 []
# 110928  [taxon:9606]                                                 []
# 110929  [taxon:9606]                                 [UniProtKB:P61204]
# 110930  [taxon:9606]                                 [UniProtKB:P84085]
# 110931  [taxon:9606]                                                 []
# 110932  [taxon:9606]     [UniProtKB:P61751, ensembl:ENSRNOP00000017692]
# 110933  [taxon:9606]     [UniProtKB:P61751, ensembl:ENSRNOP00000017692]
# 110934  [taxon:9606]     [UniProtKB:P61750, ensembl:ENSMUSP00000022429]
# 110935  [taxon:9606]                                                 []
# 110936  [taxon:9606]                                                 []
# 110937  [taxon:9606]                                                 []
# 110938  [taxon:9606]                                                 []
# 110939  [taxon:9606]                                                 []
# 110940  [taxon:9606]                                                 []
# 110941  [taxon:9606]     [UniProtKB:P61750, ensembl:ENSMUSP00000022429]
# 110942  [taxon:9606]     [UniProtKB:P61750, ensembl:ENSMUSP00000022429]
# 110943  [taxon:9606]                                                 []
# 110944  [taxon:9606]     [UniProtKB:P61751, ensembl:ENSRNOP00000017692]
# 110945  [taxon:9606]                                                 []
# 110946  [taxon:9606]     [UniProtKB:P61750, ensembl:ENSMUSP00000022429]
# 110947  [taxon:9606]                                                 []
# 110948  [taxon:9606]     [UniProtKB:P61750, ensembl:ENSMUSP00000022429]
# 110949  [taxon:9606]     [UniProtKB:P61750, ensembl:ENSMUSP00000022429]
# 110950  [taxon:9606]                                                 []
# 427558  [taxon:9606]  [MGI:MGI:99431, PANTHER:PTN000918181, SGD:S000...
# 432761  [taxon:9606]  [FB:FBgn0010348, MGI:MGI:99431, MGI:MGI:99432,...
# 433512  [taxon:9606]  [PANTHER:PTN000918181, UniProtKB:P51823, WB:WB...
# 434163  [taxon:9606]             [PANTHER:PTN000195680, SGD:S000002351]
# 436322  [taxon:9606]  [FB:FBgn0000115, MGI:MGI:99431, PANTHER:PTN000...
# 469812  [taxon:9606]  [PANTHER:PTN002270643, UniProtKB:P18085, UniPr...
# 473198  [taxon:9606]  [FB:FBgn0010348, MGI:MGI:1927136, MGI:MGI:1933...
# 473793  [taxon:9606]  [MGI:MGI:99433, MGI:MGI:99434, PANTHER:PTN0024...

# %%
len(umi2go.drop_duplicates(["umi_id","GO_NAME"]))
# Out:
# 331335

# %%
len(umis2go_out)
# Out:
# 331335

# %%
tx_symbols
# Out:
# ENST00000632684     AC245427.8
# ENST00000434970          TRDD2
# ENST00000448914          TRDD3
# ENST00000415118          TRDD1
# ENST00000631435     AC239618.6
# ENST00000390567       IGHD1-26
# ENST00000439842       IGHD7-27
# ENST00000454908        IGHD1-1
# ENST00000390583       IGHD3-10
# ENST00000390572       IGHD2-21
# ENST00000390571       IGHD3-22
# ENST00000454691        IGHD6-6
# ENST00000390588        IGHD5-5
# ENST00000390581       IGHD5-12
# ENST00000390574       IGHD6-19
# ENST00000450276       IGHD1-20
# ENST00000431870       IGHD4-17
# ENST00000414852        IGHD4-4
# ENST00000390590        IGHD3-3
# ENST00000390584        IGHD3-9
# ENST00000452198       IGHD6-25
# ENST00000634154       IGHD4-11
# ENST00000631895       IGHD5-12
# ENST00000633030       IGHD4-23
# ENST00000632524       IGHD7-27
# ENST00000633009       IGHD1-26
# ENST00000634070       IGHD6-25
# ENST00000390591        IGHD2-2
# ENST00000431440       IGHD4-11
# ENST00000390580       IGHD6-13
#                       ...
# ENST00000638650         LILRP1
# ENST00000639410    AC245128.32
# ENST00000638534        KIR2DP1
# ENST00000638315        KIR2DP1
# ENST00000639315         LILRP1
# ENST00000640480    AC245128.28
# ENST00000640126         LILRP1
# ENST00000639803    AC245128.27
# ENST00000640261         LILRP1
# ENST00000639084    AC245128.36
# ENST00000640737        KIR2DP1
# ENST00000640708        KIR2DP1
# ENST00000638418         LILRP1
# ENST00000639721    AC245128.18
# ENST00000640186        KIR2DP1
# ENST00000640503         LILRP1
# ENST00000639731    AC245128.33
# ENST00000640875        KIR2DP1
# ENST00000640079         LILRP1
# ENST00000638503    AC245128.25
# ENST00000639733        KIR2DP1
# ENST00000640864        KIR2DP1
# ENST00000639790         LILRP1
# ENST00000639660    AC245128.20
# ENST00000638652         LILRP1
# ENST00000639103    AC245128.37
# ENST00000640196        KIR2DP1
# ENST00000639620         LILRP1
# ENST00000638457    AC245128.19
# ENST00000638565        KIR2DP1
# Length: 179973, dtype: object

# %%
len(umi2go)
# Out:
# 713468

# %%
# Out:
# 87352

# %%
genes2go_out = umi2go[["GO_NAME","GO_ID","symbol","ncbi_gene"]].drop_duplicates()
genes2go_out.to_csv(os.path.join(OUTDIR_GO, "genes2go.csv"),index=False)

# %%
a0 = ontologies.sort_values("DB_Object_Symbol")

#for each cell in the selected segmentation, list all transcripts (with counts)
#that appear



umi2txall = umi2tx.join( TX_INFO,on = "transcript")
ontologies_by_symbol = ontologies.set_index(ontologies.DB_Object_Symbol)
ontologies_by_symbol["GO_NAME"] = ontologies_by_symbol.GO_ID.apply(lambda x: go[x].name).rename("GO_NAME")
umi2go=umi2txall.drop_duplicates(["umi","symbol"]).join(ontologies_by_symbol, on="symbol" )

OUTDIR_GO=os.path.join( f"/data/dd-analysis/datasets/{dsname }/goterms/")    
if not os.path.isdir(OUTDIR_GO): os.makedirs(OUTDIR_GO)

umis2go_out =umis2go_out = pd.concat([umi2go.umi,umi2go.GO_NAME,umi2go.GO_ID],axis=1).drop_duplicates()
umis2go_out.to_csv(os.path.join(OUTDIR_GO, "umis2go.csv"),index=False)

gene2go_out = umi2go[["GO_NAME","GO_ID","symbol","ncbi_gene"]].drop_duplicates()
gene2go_out.to_csv(os.path.join(OUTDIR_GO, "gene2go.csv"),index=False)

OUTDIR_GS=os.path.join( f"/data/dd-analysis/datasets/{dsname }/genesymbols/")    
if not os.path.isdir(OUTDIR_GS): os.makedirs(OUTDIR_GS)
# segment_symbols.to_csv(os.path.join(OUTDIR_GS, "segment_symbols.csv"),index = False)
umi_symbols = umi2txall[["umi","symbol","desc","ensembl_gene","ncbi_gene"]]     
umi_symbols.to_csv(os.path.join(OUTDIR_GS,"umi_symbols.csv"),index= False)

OUTDIR_GIDS=os.path.join( f"/data/dd-analysis/datasets/{dsname }/geneids/")    
if not os.path.isdir(OUTDIR_GIDS): os.makedirs(OUTDIR_GIDS)
umi_genes = pd.concat([umi2txall.umi, umi2txall.ensembl_gene, umi2txall.ncbi_gene],axis = 1)
umi_genes.to_csv(os.path.join(OUTDIR_GIDS,"umi_genes.csv"),index = False)

OUTDIR_SEGMENTS=os.path.join(f"/data/dd-analysis/datasets/{dsname }/segments/")
if not os.path.isdir(OUTDIR_SEGMENTS):os.makedirs(OUTDIR_SEGMENTS)
umi_to_seg_df = segdf[["umi","seg"]]
umi_to_seg_df.to_csv(os.path.join(OUTDIR_SEGMENTS,"umi2seg.csv"),index = False)
